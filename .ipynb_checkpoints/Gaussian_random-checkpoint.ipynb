# %%
import random
import matplotlib.pyplot as plt
import numpy as np
N = 100
x = [x for x in range(N)]
y = [np.random.normal(loc=0.0, scale = 1) for _ in range(N)]
# y = [random.normal(0,1) for _ in range(N)]

plt.plot(x,y,'ro')
plt.plot(x,y,'b-')
plt.show()
